# %%
# !pip install mss
# !pip install matplotlib
# !pip install tensorboardX python-dotenv
# Out:
# Requirement already satisfied: mss in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (9.0.1)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorboardX in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (2.6.2.2)
# Requirement already satisfied: python-dotenv in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from tensorboardX) (1.24.1)
# Requirement already satisfied: packaging in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from tensorboardX) (23.2)
# Requirement already satisfied: protobuf>=3.20 in c:\my tools\environments\pytorch_2_1_0_cuda_11_8\lib\site-packages (from tensorboardX) (4.23.4)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## preparations

# %%
# debug
import time
import random
from IPython.display import clear_output
from matplotlib import pyplot as plt

# %%
import os
from dotenv import load_dotenv

EXECUTABLE_NAME = os.getenv('EXECUTABLE_NAME')
GAME_WINDOW_NAME = os.getenv('GAME_WINDOW_NAME')

# %% [markdown]
# ### camera

# %%
from src.gamenv import GameEnv

game_env = GameEnv("snes9x.exe", "mario - Snes9x 1.62.3", (20, 120, -10, -50))
camera = game_env.camera

# %%
camera.set_foreground_game()
frame = camera.get_frame()
plt.imshow(frame)

# %% [markdown]
# ### Agent

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
D = 40_000
GAMMA = 0.999
LR = 0.00007

# NUM_EPISODES = 10000
SEQUENCE_LENGTH = 100
BATCH_SIZE = 100

EPS_NUM_STEPS = 20000
EPS_START = 0.10
EPS_END = 0.005
EPS_DECAY = (EPS_START - EPS_END) / (EPS_NUM_STEPS)

action_space = 4

load_model = False
model_name = "2023_12_26_23_13_56"

# %%
import time
from itertools import count
from tensorboardX import SummaryWriter

from src.memory import Memory

timestr = time.strftime("%Y_%m_%d_%H_%M_%S")

# %%
# Initiliaze replay memory D to capacity N
replay_memory = Memory(D)
sequence = Memory(SEQUENCE_LENGTH)

# %%
from src.models.batch_model import DQN, phi
from torch import nn

# Initialize action-value function Q with random weights

lstm_n = 512
lstm_layers = 1

policy_net = DQN(action_space, lstm_n, lstm_layers).to(device) # used to store teta
target_net = DQN(action_space, lstm_n, lstm_layers).to(device) # used to store teta-1

if load_model:
    policy_net.load_state_dict(torch.load(f'./saved_models/{model_name}/policy_net'))
    
target_net.load_state_dict(policy_net.state_dict())

optimizer = torch.optim.RMSprop(policy_net.parameters(), lr=LR)
loss_fn = nn.MSELoss()

steps = 0
episode = 0
epsilon = EPS_START
# Out:
# c:\my tools\environments\pytorch_2_1_0_cuda_11_8\Lib\site-packages\torch\nn\modules\rnn.py:82: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
camera.set_foreground_game()
frame = camera.get_frame()
img = phi(observation=frame, device=device)
mean, std = img.mean([1,2]), img.std([1,2])
img = img.cpu().numpy()
img = img.transpose((1,2,0))
print(img.shape)
print(mean, std)
plt.imshow(img[:,:,0])
# Out:
# (80, 80, 3)
# tensor([-5.2154e-09,  1.8179e-07,  1.7285e-08], device='cuda:0') tensor([1.0000, 1.0000, 1.0000], device='cuda:0')

# %%
plt.imshow(img[:,:,1])

# %%
plt.imshow(img[:,:,2])

# %%
time.sleep(2)
camera.set_foreground_game()
time.sleep(0.2)

policy_net.train()

with SummaryWriter(logdir="runs/"+timestr) as writer:
    
    while steps < D*50-50:
        
        ep_rewards = 0
        ep_qvalues = 0
        ep_loss = 0
        
        # Initialise sequence s1 = {x1} and preprocessed sequenced φ1 = φ(s1)
        observation = game_env.reset()
        state = phi(observation, device)
        last_reward = 0
        # sequence.clear()
        
        
        for t in count():
            # print(len(sequence), t)

            sequence.push(state)
            sequence_state = sequence.render_simple()

            hn = torch.zeros(lstm_layers, lstm_n, dtype=torch.float32, device=device)
            cn = torch.zeros(lstm_layers, lstm_n, dtype=torch.float32, device=device)

            with torch.no_grad():
                
                q_value_action, (hn, cn) = policy_net(sequence_state, (hn, cn))
                q_value_action = q_value_action[-1:]
                q_value_action = q_value_action.max(1)
                q_value = q_value_action[0].item()
                ep_qvalues += q_value
                
            
            # With probability eps select a random action at
            epsilon = epsilon - EPS_DECAY if epsilon > EPS_END else EPS_END
            if random.uniform(0, 1) < epsilon:
                action = torch.tensor([[random.randint(0, action_space-1)]], device=device, dtype=torch.long)
            # otherwise select at = maxaQ*(phi(st), a; teta)
            else:
                action = q_value_action[1].view(1,1)
                # print(action)

            # Execute action at in emulator and observe reward rt and image xt+1
            observation, reward, game_over = game_env.step(action.item())
            
            ep_rewards += reward
            #print(reward)
            reward = torch.tensor([reward], device=device, dtype=torch.float32)

            # Set st+1 = st, at, xt+1 and preprocess phit+1 = phi(st+1)
            if game_over:
                next_state = None # ordem provavelmente errada
            else:
                next_state = phi(observation, device)
                # sequence.push(next_state)
                # rendered, next_sequence_state = sequence.render()

            #if sequence_state != None:
            #    replay_memory.push((sequence_state, action, reward, next_sequence_state))
            replay_memory.push((state, action, reward, next_state))
            
            if len(replay_memory) > BATCH_SIZE: # and steps > 200:
                loss = policy_net.q_train(target_net, optimizer, loss_fn, replay_memory.sample_sequence(BATCH_SIZE), GAMMA, lstm_n, lstm_layers, device).item()
                ep_loss += loss
                if (t+1) % SEQUENCE_LENGTH == 0:

                    clear_output(wait=True)
                    print('loss:', ep_loss, 'step:', steps, 'epsilon:', epsilon, 'last_reward:', ep_rewards, 'ep:', episode)

                    writer.add_scalar("Loss/ep_loss", ep_loss / SEQUENCE_LENGTH, steps)
                    writer.add_scalar("Reward/ep_rewards", ep_rewards / SEQUENCE_LENGTH, steps)
                    writer.add_scalar("Qvalue/ep_qvalues", ep_qvalues / SEQUENCE_LENGTH, steps)

                    ep_rewards = 0
                    ep_qvalues = 0
                    ep_loss = 0

                writer.add_scalar("Loss/loss", loss, steps)
                writer.add_scalar("Reward/reward", reward, steps)
                writer.add_scalar("Qvalue/qvalue", q_value, steps)
                writer.flush()
                
                if steps % 5000 == 0:
                    target_net.load_state_dict(policy_net.state_dict())
                    
            # sequence_state = next_sequence_state 
            state = next_state
            steps += 1
            if game_over:
                break
        episode += 1
        # writer.flush()
# Out:
# loss: 0.6011710466118529 step: 3073 epsilon: 0.5931785000000851 last_reward: -23.60000000000001 ep: 34
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 50
#      46     action = q_value_action[1].view(1,1)
#      47     # print(action)
#      48
#      49 # Execute action at in emulator and observe reward rt and image xt+1
# ---> 50 observation, reward, game_over = game_env.step(action.item())
#      52 ep_rewards += reward
#      53 #print(reward)
#
# File c:\Users\glucas\Documents\a\repos\random-things-i-do\reinforcement-learning\super_mario_world-agent\src\gamenv\gameenv.py:73, in GameEnv.step(self, action)
#      70 game_over = False
#      72 if GetForegroundWindow() != self.camera.window_handle:
# ---> 73     raise Exception(f"{GetWindowText(self.camera.window_handle)} cannot be minimized.")
#      75 #self.toggle_pause()
#      76 #print("unpaused")
#      78 if action == 0:
#
# Exception: mario - Snes9x 1.62.3 cannot be minimized.

# %%
import os

save_model_dir = './saved_models'

if not os.path.exists(f'{save_model_dir}'):
    os.mkdir(f'{save_model_dir}')
if not os.path.exists(f'{save_model_dir}/{timestr}'):
    os.mkdir(f'{save_model_dir}/{timestr}')

torch.save(policy_net.state_dict(), f'{save_model_dir}/{timestr}/policy_net')
torch.save(target_net.state_dict(), f'{save_model_dir}/{timestr}/target_net')

# %%
exit()

# %%
camera.set_foreground_game()

policy_net.eval()
while True:
    observation = game_env.reset()
    time.sleep(0.1)
    state = phi(observation, device)
    sequence.clear()
    
    for t in count():

        sequence.push(state)
        rendered = sequence.render_simple()

        hn = torch.zeros(lstm_layers, lstm_n, dtype=torch.float32, device=device)
        cn = torch.zeros(lstm_layers, lstm_n, dtype=torch.float32, device=device)
        with torch.no_grad():
            q_value_action, (hn, cn) = policy_net(rendered, (hn, cn))
            q_value_action = q_value_action[-1:]
            print(q_value_action, end="")
            q_value_action = q_value_action.max(1)
            action = q_value_action[1].view(1,1)
            print(f", actions {action}")

        observation, reward, game_over = game_env.step(action.item())
        if game_over:
            next_state = None # ordem provavelmente errada
        else:
            next_state = phi(observation, device)
        state = next_state
        if game_over:
            break

# %%
camera.set_foreground_game()
state = phi(camera.get_frame(), device)

policy_net.eval()
hn = torch.zeros(lstm_layers, lstm_n, dtype=torch.float32, device=device)
cn = torch.zeros(lstm_layers, lstm_n, dtype=torch.float32, device=device)

with torch.no_grad():
    q_value_action, (hn, cn) = policy_net(state.unsqueeze(0), (hn, cn))
    q_value_action = q_value_action[-1:]
    print(q_value_action)
